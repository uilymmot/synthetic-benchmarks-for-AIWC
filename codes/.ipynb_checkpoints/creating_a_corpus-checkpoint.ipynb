# %% [markdown]
# # Creating a Corpus
#
# This Jupyter artefact details the process to collect a sizable corpus of OpenCL kernels used for the synthetic code generation.
#
# ## Setup
# We must load the clgen repository, shown in the following code-block.

# %%
! cd /phd && ./configure --noninteractive && bash .env && bazel test //config:getconfig_test
# Out:
# CUDA found at: '/usr/local/cuda-9.0/bin/nvcc'.
# Enable CUDA support? [Y/n] yes
# Update git submodules? [Y/n] yes
# Symlink python to ~/.local/bin/python? [Y/n] yes
# Config ID: af464b58462db4ec8a5bd466bde62ce0b93e128857a4298563422fd2f132fc9d
# Git remote: https://github.com/ChrisCummins/phd.git
# Rewriting .gitmodules to use https://
#
# Created bootstrap script to install system dependencies. If this is
# your first time build this code, inspect and then run the script:
#     bash ./bootstrap.sh
# Loading:
# Loading: 0 packages loaded
# Analyzing: target //config:getconfig_test (0 packages loaded)
# INFO: Build options have changed, discarding analysis cache.
# Analyzing: target //config:getconfig_test (0 packages loaded)
# Analyzing: target //config:getconfig_test (0 packages loaded)
# Analyzing: target //config:getconfig_test (0 packages loaded)
# Analyzing: target //config:getconfig_test (23 packages loaded)
#     currently loading: @pypi__humanize_0_5_1// ... (2 packages)
# ...

# %% [markdown]
# A full test of the CLgen project gives the following:

# %%
! cd /phd && ./configure --noninteractive && bash .env && bazel test --test_output=summary --nocache_test_results //...
# Out:
# CUDA found at: '/usr/local/cuda-9.0/bin/nvcc'.
# Enable CUDA support? [Y/n] yes
# Update git submodules? [Y/n] yes
# Symlink python to ~/.local/bin/python? [Y/n] yes
# Config ID: af464b58462db4ec8a5bd466bde62ce0b93e128857a4298563422fd2f132fc9d
# Git remote: https://github.com/ChrisCummins/phd.git
# Rewriting .gitmodules to use https://
#
# Created bootstrap script to install system dependencies. If this is
# your first time build this code, inspect and then run the script:
#     bash ./bootstrap.sh
# Loading:
# Loading: 0 packages loaded
# INFO: Build options have changed, discarding analysis cache.
# Analyzing: 661 targets (165 packages loaded)
# Analyzing: 661 targets (165 packages loaded)
# Analyzing: 661 targets (165 packages loaded)
#     currently loading: @bazel_tools//platforms
# ...

# %% [markdown]
# We use an old version of clgen to scrape kernels from github.

# %% [markdown]
# ## Scraping Github
#
# To begin we must collect a large number of samples of OpenCL kernels.
# Fortunately, GitHub has thousends of these sources contributed by the community.

# %% [markdown]
# import d
#
# #The data-base was generated by mining github for OpenCL kernel files as training samples.
# #10k files were used to generate this training corpus.
# #These can be reproduced using clgen-create-db:
# #
# # Generate an API token by following the instructions here:
# #   https://help.github.com/articles/creating-an-access-token-for-command-line-use/>
# #
# # From the command line, run:
# #
# #   $ export GITHUB_USERNAME=[your-username]
# #   $ export GITHUB_PW=[your-password]
# #   $ export GITHUB_TOKEN=[your-api-token]
# #   $ clgen-create-db --github github.db
# #   $ clgen-fetch-github github.db
# #
# # instructions to generate the github api token can be found [here]<https://help.github.com/articles/creating-an-access-token-for-command-line-use>
